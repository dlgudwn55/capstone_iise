# %%
import time
import warnings
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# 페이지 끝까지 스크롤
def scroll_down():
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)

# 게시글 설명 추출
def get_caption(link):
    driver.get(link)
    time.sleep(4)
    try:
        caption = driver.find_element(By.CSS_SELECTOR, 'h1._ap3a._aaco._aacu._aacx._aad7._aade').text
        print(caption)
    except:
        caption = "캡션 찾을 수 없음"
    return caption

warnings.filterwarnings(action='ignore')

driver = webdriver.Edge()
url = 'https://www.instagram.com'
driver.get(url)
time.sleep(1)

email = 'leehj7934'
password = 'gudwn55!'

input_li = driver.find_elements(By.TAG_NAME, 'input')
print("input_li:",input_li)
input_li[0].send_keys(email)
input_li[1].send_keys(password)
input_li[1].send_keys(Keys.RETURN)

time.sleep(5)

# 로그인 정보 저장 여부 ("나중에 하기 버튼 클릭")
btn_later1 = driver.find_element(By.CLASS_NAME, 'x1i10hfl')
btn_later1.click()
time.sleep(5)

# 알림 설정 ("나중에 하기 버튼 클릭")
# btn_later2 = driver.find_element(By.CLASS_NAME, '_a9--._a9_1')
# btn_later2.click()
# time.sleep(3)

REGIONS_KR = [
    '부산',
    '대구','군위',
    '인천','강화도','옹진',
    '경기도','가평','연천',
    '강원도','고성','삼척','양구','양양','영월','정선','철원','태백','평창','홍천','화천','횡성',
    '충북','괴산','단양','보은','영동','옥천','제천',
    '충남','공주','금산','논산','보령','부여','서천','예산','청양','태안',
    '전북','고창','김제','남원','무주','부안','순창','임실','장수','정읍','진안',
    '전남','강진','고흥','곡성','구례','담양','보성','신안','영광','영양','완도','장성','장흥','진도','함평','해남','화순',
    '경북','고령','문경','봉화','상주','성주','안동','영덕','영향','영주','영천','울릉도','울진','의성','청도','청송',
    '경남','거창','경남고성','남해','밀양','산청','의령','창녕','하동','함안','합천',
]

regions = []
captions = []
data = {
    'regions': regions,
    'captions': captions,
}

for region in REGIONS_KR:

    hashtag = region + "여행"
    driver.get(f"https://www.instagram.com/explore/tags/{hashtag}/")
    time.sleep(2)

    # 링크 수집 및 스크롤
    post_links = set()
    for _ in range(5):
        posts = driver.find_elements(By.XPATH, '//a[contains(@href, "/p/")]')
        for post in posts:
            post_links.add(post.get_attribute('href'))
        scroll_down()

    # 링크 수집 종료 후 콘솔에 표시
    links_cnt = len(post_links)
    print(f"총 {len(post_links)}개의 게시물 URL을 수집했습니다.")

    for i, link in enumerate(post_links):
        regions.append(region)
        caption = get_caption(link)     
        captions.append(caption)
        # captions.append(caption.text)

    # for i, cap in enumerate(captions):
    #     print(f"Post {i}: {cap}")

driver.quit()
# Out:
# input_li: [<selenium.webdriver.remote.webelement.WebElement (session="4d3bdf29ce281e635ba69444097184d8", element="f.34AEEBC00E48ED32367085F6522B59A8.d.7AEF83B55575185635560D78A7A4347E.e.13")>, <selenium.webdriver.remote.webelement.WebElement (session="4d3bdf29ce281e635ba69444097184d8", element="f.34AEEBC00E48ED32367085F6522B59A8.d.7AEF83B55575185635560D78A7A4347E.e.15")>]
# 총 111개의 게시물 URL을 수집했습니다.
# 비키니 미스..🫠
# 뒤죽박죽 행복했던 주말의 부산 🩵
# 부산 광안리 역대급 밤분위기 신상카페 추천 ☕️✨
# (리그램) @iloveyouyacht 예약 전 010-8866-8646으로 전화주세요
# 🏹✨🐚🩵🐠🫧🍕
#
# ㅂㅏ다에
# 수영복 입자마자 뜯어진 이슈 ~ ><
# @lafs_in_busan
# @busan_orange
# @busan_orange
# @busan_orange
# [새콤달콤 필먹각인 부산 딸기맛집 곳 총정리🍓]
# @busan_orange
# (리그램) @yachtholic 부산여행
# #숩니여름 #해운대
# @busan_orange
# @busan_orange
# @busan_orange
# 너무 예쁜 부산 기장여행2탄
# 이제 가을이다🍂🍁
# 가
# 아침수영으로 엄청 탄 이슈 #그랜드조선부산 #여름이였다
# 부산 좋아 🏖️🌊
# @busan_orange
# 날씨부터 완벽했던 부산여행 기록🩵
# (리그램) @yachtholic 부산여행
# #초대 #Clubdoasis
# 중간에 땅..꼬마.. 아니고 땅에 가까이 있는 나 🫠☀️🐚🙃
# 물놀이 막차 탑승🫧🩵 #해운대클럽디오아시스🌴 #부산여행
# (리그램) @yachtholic 부산여행
# 바다는 밤바다가 더 예쁜거 같아요🌌
# 애들아 벌써 9월이라니ㅣ??!!몇일 전까지만 해두
# (리그램) @yachtholic 부산여행
# 제가 힐링이 필요할 떄 때마다 꼭 찾게되는 카페가 있는데요
# 아침에한번 저녁에한번 ,하루에 두번씩 원없이 수영했던 마지막 여름 부산여행🏊‍♀️ 🌊🪽
# 드 디 어 무화과 케이크를 먹고 행복해지다 ♬⋆꩜♪.•*
# [서면에 있는 데이트코스 테마별 270가지 총정리💕]
# #부산팜파스
# @busan_orange
# @cloud.shop._.busan
# 8월 마지막 여행 🕶️
# .
# (리그램) @yachtholic 부산여행
# 우리 그래도 여름 즐겨따🏖️🍹👙🌞
# 굿바이
# (리그램) @yachtholic 부산여행
# @busan_orange
# #광안리 에서 프라이빗 하게
# 부산무화과맛집 9곳 좌표공유⚜️⁉️
# 올여름 마지막 바다 여행 🐠
# (리그램) @yachtholic 부산여행
# @august_7ven 맑은 어린이날이었으면 더더욱 좋았겠지만 비가 추적추적내리는 금요일도 운치있네요 😄
# 완벽하게 즐긴 여름 ⛱️🩵
# @busan_orange
# (리그램) @busanyachtpropose ✅세심한 ALL INCLUSIVE 서비스
# #해운대유람선 #부산여행 #해운대여행
# 🍀 행운을 찾아주세요🎶 🍀
#
# 저
# @busan_orange
# ㅇㅕ름이었다🫧🕊️💎
# 📍혼자 잘 돌아다니는 사람 모여라📍
# #
# (리그램) @yachtholic 부산여행
# (리그램) @busanyachtpropose ✅세심한 ALL INCLUSIVE 서비스
# 아니, 갑자기 미친듯이 선선해진다고요?! 가을이 온다구요?!🍂🍂
# (리그램) @yachtholic 부산여행
# @busan_orange
# @busan_orange
# 정말 역대급으로 예쁜 부산하늘☁️
# (리그램) @yachtholic 부산여행
# 팔에 용타투 작업 :)
# 부산, 드디어 축제 일정 확정된 불꽃놀이🎆
# .
# 여기 해외아니고 부산이예요,,🌴 #광고 현시각 부산에서 가장 예쁜 풀빌라의 등장, 앞서 릴스로 올린 역대급 신상숙소 [더비치하우스] 입니다, 🫧
# 최초공개 모르면 호구되는 숨은 부산야경명소 3탄 🌉
# [먹킷 접수해야 할 영도 찐맛집 모음집🍽️]
# 해운대 바다 너무 예쁘더라🌞🌊🌅
# .
# @busan_orange
# @busan_orange
# @stay.seoseoilo
# 🧳 [부산에서 하루 놀기] PART 5. 부산 오시리아편
# 하이디라오가 쏘아올린 부산여행🌌💙
# 역광 살려줘
# (리그램) @yachtholic 부산여행
# @cloud.shop._.busan
# 한번쯤 꼭 가보고싶은 핫플☺
# @busan_orange
# @busan_orange
# 도심 속 힐링스팟 ✨ ‘도시별장 김해본점‘ 입니다
# 벌써 9월이라니 ..또르륵
# 내 조랑말🐕🫶🏻#dobermanpinscher
# (리그램) @perpercoffee 요거트그래놀라와 무화과의 계절🩷
# 윤슬보며 멍 때리던 시간💙
# 바다 실컷 보고 오기🐟🧢🐬👕🥣
# My summer☀️⛱️🩵
# 📌미리 준비하는 경남·경북·부산 가을 여행지📌
# 부은 얼굴로 추억의 #파라다이스호텔 갔다가
# @busan_orange
# @busan_orange
# (리그램) @busanyachtpropose ✅세심한 ALL INCLUSIVE 서비스
# 💖11월 부산 귀여운 팝업 싹 정리해줌💖
# @club_belpos_merchandiser
# @busan_orange
# #부산#부산여행 #부산카페 #부산데이트 #부산핫플 #부산대 #서면 #방학 #휴가 #여자코디 #여자 #여자데일리룩 #일상소통 #일상기록 #일상룩 #운동하는여자 #운동 #운동소통 #운동녀 #필라테스 #헬스 #헬린이
# (리그램) @yachtholic
# @cloud.shop._.busan
# [🎇2024 하반기 부산 축제 총정리🎇]
# 지
# @club_belpos_merchandiser
# (리그램) @yachtholic 부산여행
# @busan_orange
# 부산 여행에 잘 어울리는 휴양지 어디로 갈지 아직 정하지 못했다면
# 장마철엔 역시 실내데이트징☔
# @busan_orange
# 총 87개의 게시물 URL을 수집했습니다.
# 반영샷 찍기 좋은 곳 🪞
# 🦄대구 최대규모 리빙 편집샵 ‘피클샵’ 만촌동 2호점 오픈
# 소떡소떡을 먹을까 츄러스를 먹을까
# [해랑사]
# 💜여기가 맥문동맛집💜
# 일
# 🧡히츠마부시 쫀맛집💛
# 매
# 🌟이번 크리스마스는 #이월드 가 다했다!🌟
# 서문시장에서 또 김밥 먹는 만화
# [깔끔하게 정리해 본 대구데이트 270가지 총정리💗]
# 분위기 좋은 공간의 힘.・。.・゜✭
# .
# 총 66개의 게시물 URL을 수집했습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 93
#      91 for i, link in enumerate(post_links):
#      92     regions.append(region)
# ---> 93     caption = get_caption(link)
#      94     captions.append(caption)
#      95     # captions.append(caption.text)
#      96
#      97 # for i, cap in enumerate(captions):
#      98 #     print(f"Post {i}: {cap}")
#
# Cell In[13], line 16, in get_caption(link)
#      14 def get_caption(link):
#      15     driver.get(link)
# ---> 16     time.sleep(4)
#      17     try:
#      18         caption = driver.find_element(By.CSS_SELECTOR, 'h1._ap3a._aaco._aacu._aacx._aad7._aade').text
#
# KeyboardInterrupt:

# %%
import pandas as pd

df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 df = pd.DataFrame(data)
#       4 df
#
# File d:\capstone\iise\capstone_iise\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File d:\capstone\iise\capstone_iise\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File d:\capstone\iise\capstone_iise\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File d:\capstone\iise\capstone_iise\Lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length
